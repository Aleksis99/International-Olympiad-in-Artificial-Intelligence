# %% [markdown]
# # Bigram Language Model
#
# This notebook implements a classic statistical Bigram Language Model from scratch.

# %% [markdown]
# ### 1. Imports
#
# First, we import the necessary libraries. `collections` is used for efficiently counting word occurrences.

# %%
import random
from collections import defaultdict, Counter
import re
import string

# %% [markdown]
# Download tiny Shakespeare dataset

# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2025-06-24 13:05:19--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.06s
#
# 2025-06-24 13:05:20 (17.3 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %% [markdown]
# ### 2. Prepare the tables

# %%
def remove_punctuation(s):
    """
    Removes all punctuation from a string and converts it to lowercase.
    """
    return s.lower().translate(str.maketrans('', '', string.punctuation))

# %%
remove_punctuation("Hello. How are you?")
# Out:
# 'hello how are you'

# %%
bigram_counts = defaultdict(Counter)
unigram_counts = Counter()
vocabulary = set()
tokens = []
for line in open("input.txt", encoding='utf-8'):
    sentence = remove_punctuation(line.rstrip()).split()
    tokens.extend(["[START]"] + sentence + ["[END]"])


unigram_counts = Counter(tokens)
vocabulary = set(tokens)

for i in range(len(tokens) - 1):
    prev_word, current_word = tokens[i], tokens[i+1]
    bigram_counts[prev_word][current_word] += 1

# %% [markdown]
# ### 3. Inspect the Trained Model
#
# Let's look at the vocabulary and the learned bigram counts for a sample word.

# %%
print("--- Model Vocabulary ---")
print(sorted(list(vocabulary)))
print("\n--- Bigram Counts (sample for 'i') ---")
print(bigram_counts['i'])
# Out:
# --- Model Vocabulary ---
# ['3', '[END]', '[START]', 'a', 'abandond', 'abase', 'abate', 'abated', 'abbey', 'abbot', 'abed', 'abels', 'abet', 'abhor', 'abhorrd', 'abhorred', 'abhorring', 'abhors', 'abhorson', 'abide', 'abides', 'abilities', 'ability', 'abilitys', 'abject', 'abjects', 'abjured', 'able', 'ableeding', 'aboard', 'abode', 'abodements', 'aboding', 'abominable', 'abortive', 'abound', 'aboundst', 'about', 'above', 'abraham', 'abrahams', 'abreast', 'abroach', 'abroad', 'absence', 'absent', 'absolute', 'absolutely', 'absolved', 'abstains', 'abstinence', 'abstract', 'abundance', 'abundant', 'abundantly', 'abuse', 'abused', 'abuses', 'abusing', 'abysm', 'accent', 'accents', 'accept', 'acceptance', 'access', 'accessary', 'accident', 'accidental', 'accidentally', 'accidents', 'acclamations', 'accommodations', 'accompanied', 'accompany', 'accomplish', 'accomplishd', 'accomplished', 'accompt', 'accord', 'according', 'accordingly', 'accords', 'account', 'accountant', 'accounted', 'accountst', 'accoutrements', 'accursed', 'accurst', 'accusation', 'accusations', 'accuse', 'accused', 'accuser', 'accusers', 'accuses', 'accuseth', 'accustomd', 'ache', 'aches', 'achieve', 'achieved', 'aching', 'acknowledge', 'acknowledged', 'acorn', 'acquaint', 'acquaintance', 'acquainted', 'acquit', 'acquittance', 'acre', 'across', 'act', 'acted', 'acting', 'action', 'actions', 'actor', 'actors', 'acts', 'ad', 'adage', 'adam', 'adams', 'aday', 'add', 'added', 'adder', 'adders', 'adding', 'addition', 'addle', 'address', 'adds', 'adheres', 'adieu', 'adjacent', 'adjudged', 'administer', 'admirable', 'admiral', 'admiration', 'admire', 'admired', 'admiring', 'admit', 'admits', 'admitted', 'admitting', 'admonition', 'ado', 'adoa', 'adoing', 'adonis', 'adopt', 'adopted', 'adoptedly', 'adopts', 'adoreth', 'adorn', 'adorned', 'adorns', 'adrian', 'adriatic', 'adulterate', 'adulteress', 'adulterous', 'adultery', 'advance', 'advanced', 'advancement', 'advantage', 'advantaged', 'advantageous', 'advantages', 'advantaging', 'adventure', 'adversaries', 'adversary', 'adverse', 'adversely', 'adversity', 'adversitys', 'advertise', 'advertised', 'advertising', 'advice', 'advise', 'advised', 'advisings', 'advocate', 'advocates', 'adying', 'aeacides', 'aedile', 'aediles', 'aeneas', 'aery', 'aerys', 'aesop', 'afar', 'afeard', 'affability', 'affable', 'affair', 'affairs', 'affect', 'affected', 'affecting', 'affection', 'affections', 'affects', 'affectst', 'affianced', 'affied', 'afflict', 'afflicted', 'affliction', 'afflicts', 'afford', 'affords', 'affray', 'affright', 'affrighted', 'affrights', 'affront', 'afire', 'afoot', 'afore', 'afraid', 'afresh', 'afric', 'african', 'after', 'afterdinners', 'afterlove', 'aftermeeting', 'afternoon', 'afterward', 'afterwards', 'again', 'againbut', 'against', 'againsti', 'agamemnons', 'agatestone', 'age', 'aged', 'agenor', 'agent', 'agents', 'ages', 'aggravate', 'agile', 'agletbaby', 'ago', 'agony', 'agree', 'agreed', 'agreeing', 'agreement', 'agrees', 'agrippa', 'aground', 'agrowing', 'ague', 'agued', 'agues', 'ah', 'ahigh', 'ahold', 'aid', 'aided', 'aiding', 'aidless', 'ailest', 'aim', 'aimd', 'aiming', 'aims', 'air', 'aired', 'airs', 'airy', 'ajax', 'alabaster', 'alack', 'alacrity', 'alarms', 'alarum', 'alarums', 'alas', 'albans', 'albeit', 'albion', 'albions', 'alce', 'alcides', 'alderman', 'ale', 'alehouse', 'alewife', 'alexander', 'alias', 'alighted', 'alike', 'alive', 'all', 'alla', 'allamazed', 'allay', 'allayd', 'allaying', 'allays', 'allbuilding', 'allcheering', 'allegiance', 'allending', 'allhail', 'allhallond', 'allhating', 'alliance', 'allied', 'allies', 'alligator', 'allnay', 'allot', 'allow', 'allowance', 'allowd', 'allowed', 'allowing', 'alls', 'allseeing', 'allseer', 'allsouls', 'allwe', 'ally', 'almost', 'alms', 'almsdeed', 'almsmans', 'alone', 'along', 'alonso', 'aloof', 'aloud', 'alps', 'already', 'also', 'alter', 'alteration', 'alterd', 'altered', 'altering', 'alters', 'although', 'altitude', 'altogether', 'alway', 'always', 'am', 'amain', 'a ...
#
# --- Bigram Counts (sample for 'i') ---
# Counter({'am': 373, 'have': 351, 'will': 276, 'do': 165, 'would': 145, 'know': 131, '[END]': 123, 'say': 89, 'the': 89, 'pray': 83, 'must': 79, 'think': 73, 'had': 72, 'shall': 70, 'cannot': 68, 'was': 68, 'may': 66, 'should': 62, 'can': 58, 'see': 55, 'did': 55, 'thank': 41, 'be': 38, 'fear': 38, 'mean': 36, 'come': 34, 'hope': 33, 'hear': 32, 'not': 32, 'love': 31, 'could': 30, 'beseech': 29, 'saw': 29, 'warrant': 27, 'never': 27, 'speak': 25, 'tell': 24, 'thought': 22, 'dare': 22, 'prithee': 21, 'that': 21, 'were': 21, 'live': 18, 'go': 18, 'take': 18, 'in': 18, 'came': 16, 'give': 16, 'might': 16, 'to': 16, 'wish': 14, 'with': 14, 'swear': 14, 'make': 13, 'said': 13, 'but': 13, 'told': 13, 'heard': 12, 'find': 12, 'doubt': 12, 'charge': 12, 'like': 
list': 2, 'smell': 2, 'lost': 2, 'show': 2, 'subscribe': 2, 'profess': 2, 'more': 2, 'thus': 2, 'your': 2, 'gods': 2, 'cried': 2, 'sin': 1, 'any': 1, 'considering': 1, 'sprang': 1, 'drop': 1, 'select': 1, 'fought': 1, 'blush': 1, 'sometime': 1, 'utter': 1, 'cant': 1, 'sawt': 1, 'fled': 1, 'point': 1, 'direct': 1, 'change': 1, 'inform': 1, 'end': 1, 'surcease': 1, 'ought': 1, 'banish': 1, 'sup': 1, 'also': 1, 'clip': 1, 'first': 1, 'lame': 1, 'urged': 1, 'minded': 1, 'kneeld': 1, 'showd': 1, 'melt': 1, 'carried': 1, 'prate': 1, 'holp': 1, 'paint': 1, 'accuse': 1, 'raised': 1, 'pawnd': 1, 'seemd': 1, 'halt': 1, 'laid': 1, 'run': 1, 'awhile': 1, 'invocate': 1, 'pour': 1, 'lament': 1, 'nothing': 1, 'some': 1, 'forsooth': 1, 'injure ...

# %%
len(vocabulary)
# Out:
# 12850

# %%
len(vocabulary) ** 2 / 1e6
# Out:
# 165.1225

# %%
len(vocabulary) ** 2 * 4  / 1e6 # MB
# Out:
# 660.49

# %%
bigram_probabilities = {}
for prev_word, bigrams in bigram_counts.items():
    total_count = unigram_counts[prev_word]
    for current_word, count in bigrams.items():
        bigram_probabilities[(prev_word, current_word)] = count / total_count

# %%
print(bigram_probabilities['i', "am"])
# Out:
# 0.08016333548248442

# %%
print(bigram_probabilities['i', "hate"])
# Out:
# 0.002364066193853428

# %%
print(bigram_probabilities['am', "i"])
# Out:
# 0.09846827133479212

# %% [markdown]
# ### 4. Generate text

# %%
def generate_text(vocabulary, bigram_probabilities, max_length=50):
    """
    Generates text using the trained bigram model.
    """
    generated_words = []
    current_word = "[START]"

    for _ in range(max_length):
        words, probabilities = [], []
        for word in vocabulary:
            words.append(word)
            if (current_word, word) not in bigram_probabilities:
                probabilities.append(0)
            else:
                probabilities.append(bigram_probabilities[current_word, word])

        next_word = random.choices(words, weights=probabilities, k=1)[0]

        if next_word == "[END]":
            if generated_words:
                break
            else:
                current_word = "[START]"
                continue
        generated_words.append(next_word)
        current_word = next_word

    text = ' '.join(generated_words)
    if text:
        return text.capitalize()
    return "Could not generate text."

# %%
poem = []
for i in range(5):
    generated_sentence = generate_text(vocabulary, bigram_probabilities, max_length=50)
    poem.append(generated_sentence)
print('\n'.join(poem))
# Out:
# This good friend unless he does make all the fight
# And these
# Coriolanus
# How now choplogic what work
# Hastings i promise of many goodly day

# %%
poem = []
for i in range(25):
    generated_sentence = generate_text(vocabulary, bigram_probabilities, max_length=50)
    poem.append(generated_sentence)
print('\n'.join(poem))
# Out:
# I am too ominous to sleep under your sword and his or that thou do no brother i will in one half by my lord youll not have
# Slandering a pin
# Was done
# Even in bosworth field
# Doubtless burgundy
# Subject
# First provost
# Provost
# I do confess to many fly ah montague
# Most swoln that hath this may hang all i pray you were but lusty and strip myself secure in the very windows that is caius marcius banishment
# Well said hermione
# Notable
# Thrusts and his sake let me
# Will
# Polixenes
# Well
# This chamber put on his own doth command no my nose that still in parliament
# Upon your grant this outwardsainted deputy
# Arithmetic
# Tybalt
# I bear his eye advance
# If she tongue i pray thee and dissolution hangeth over a hall a statesman all the hand was my waters swell before
# That at my soul
# But with a sin of thy
# Queen elizabeth
